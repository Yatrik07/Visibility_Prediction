# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler 
from scipy.cluster.hierarchy import dendrogram , linkage

# %%
df=  pd.read_csv("InputFile.csv")

df.head()
# Out:
#                   DATE  VISIBILITY  DRYBULBTEMPF  WETBULBTEMPF  DewPointTempF  \
# 0  2010-01-01 00:51:00         6.0          33.0          32.0           31.0
# 1  2010-01-01 01:51:00         6.0          33.0          33.0           32.0
# 2  2010-01-01 02:51:00         5.0          33.0          33.0           32.0
# 3  2010-01-01 03:51:00         5.0          33.0          33.0           32.0
# 4  2010-01-01 04:51:00         5.0          33.0          32.0           31.0
#
#    RelativeHumidity  WindSpeed  WindDirection  StationPressure  \
# 0              92.0        0.0            0.0            29.97
# 1              96.0        0.0            0.0            29.97
# 2              96.0        0.0            0.0            29.97
# 3              96.0        0.0            0.0            29.95
# 4              92.0        0.0            0.0            29.93
#
#    SeaLevelPressure  Precip
# 0             29.99    0.01
# 1             29.99    0.02
# 2             29.99    0.02
# ...

# %%
df.iloc[402 , :]
# Out:
# VISIBILITY           2.50
# DRYBULBTEMPF        39.00
# RelativeHumidity    96.00
# WindSpeed           11.00
# WindDirection       50.00
# SeaLevelPressure    29.78
# Precip               0.15
# Name: 402, dtype: float64

# %%
df.drop("DATE" , inplace=True , axis=1)

# %%
plt.figure(figsize=(10,10),dpi=200)
sns.heatmap(df.corr() , annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(10,10),dpi=200)
sns.heatmap(df.drop(['WETBULBTEMPF','DewPointTempF'] , axis=1).corr() , annot=True)
# Out:
# <AxesSubplot:>

# %%
df.drop(['WETBULBTEMPF','DewPointTempF','StationPressure'] , inplace=True , axis=1)

# %%
df.head()
# Out:
#    VISIBILITY  DRYBULBTEMPF  RelativeHumidity  WindSpeed  WindDirection  \
# 0         6.0          33.0              92.0        0.0            0.0
# 1         6.0          33.0              96.0        0.0            0.0
# 2         5.0          33.0              96.0        0.0            0.0
# 3         5.0          33.0              96.0        0.0            0.0
# 4         5.0          33.0              92.0        0.0            0.0
#
#    SeaLevelPressure  Precip
# 0             29.99    0.01
# 1             29.99    0.02
# 2             29.99    0.02
# 3             29.97    0.02
# 4             29.96    0.02

# %%
for i in df.columns:
    plt.figure()
    sns.distplot(df[i])
    plt.show()
# Out:
# C:\Users\Yatrik\anaconda3\envs\Hackathon\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Yatrik\anaconda3\envs\Hackathon\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
for i in df.columns:
    plt.figure()
    sns.boxplot(df[i])
    plt.show()
# Out:
# C:\Users\Yatrik\anaconda3\envs\Hackathon\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Yatrik\anaconda3\envs\Hackathon\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
df.isna().sum()
# Out:
# VISIBILITY          0
# DRYBULBTEMPF        0
# RelativeHumidity    0
# WindSpeed           0
# WindDirection       0
# SeaLevelPressure    0
# Precip              0
# dtype: int64

# %% [markdown]
# ### No missing values

# %%
scalar = StandardScaler()
scaled_df = scalar.fit_transform(df.drop("VISIBILITY" , axis=1) )

# %%
df.head()
# Out:
#    VISIBILITY  DRYBULBTEMPF  RelativeHumidity  WindSpeed  WindDirection  \
# 0         6.0          33.0              92.0        0.0            0.0
# 1         6.0          33.0              96.0        0.0            0.0
# 2         5.0          33.0              96.0        0.0            0.0
# 3         5.0          33.0              96.0        0.0            0.0
# 4         5.0          33.0              92.0        0.0            0.0
#
#    SeaLevelPressure  Precip
# 0             29.99    0.01
# 1             29.99    0.02
# 2             29.99    0.02
# 3             29.97    0.02
# 4             29.96    0.02

# %%
pd.DataFrame(scaled_df)
# Out:
#               0         1         2         3         4          5
# 0     -1.285227  1.366308 -1.844489 -1.825118 -0.154010   0.125046
# 1     -1.285227  1.567325 -1.844489 -1.825118 -0.154010   0.401587
# 2     -1.285227  1.567325 -1.844489 -1.825118 -0.154010   0.401587
# 3     -1.285227  1.567325 -1.844489 -1.825118 -0.239455   0.401587
# 4     -1.285227  1.366308 -1.844489 -1.825118 -0.282178   0.401587
# ...         ...       ...       ...       ...       ...        ...
# 75078  1.186858  1.165291 -1.352767  0.310601 -0.025841  -0.151495
# 75079  0.784426  1.768341  0.286307 -1.453689 -0.068564  31.927227
# 75080  0.899407  1.567325 -1.844489 -1.825118  0.059604   0.125046
# 75081  0.956897  1.466816 -1.024952 -1.360831 -0.025841   0.125046
# 75082  0.956897  1.617579 -1.844489 -1.825118  0.016881  -0.151495
#
# [75083 rows x 6 columns]

# %% [markdown]
# ## Dendrogram

# %%
link = linkage(scaled_df , method='ward')
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Input In [18], in <cell line: 1>()
# ----> 1 link = linkage(scaled_df , method='ward')
#
# File ~\anaconda3\envs\Hackathon\lib\site-packages\scipy\cluster\hierarchy.py:1060, in linkage(y, method, metric, optimal_ordering)
#    1056         if np.all(y >= 0) and np.allclose(y, y.T):
#    1057             _warning('The symmetric non-negative hollow observation '
#    1058                      'matrix looks suspiciously like an uncondensed '
#    1059                      'distance matrix')
# -> 1060     y = distance.pdist(y, metric)
#    1061 else:
#    1062     raise ValueError("`y` must be 1 or 2 dimensional.")
#
# File ~\anaconda3\envs\Hackathon\lib\site-packages\scipy\spatial\distance.py:2250, in pdist(X, metric, out, **kwargs)
#    2248 if metric_info is not None:
#    2249     pdist_fn = metric_info.pdist_func
# ...

# %%
dendrogram?

# %%
import joblib
joblib.dump(scaled_df , 'sdata.pickle')
# Out:
# ['sdata.pickle']

# %%
df.head()
# Out:
#    VISIBILITY  DRYBULBTEMPF  RelativeHumidity  WindSpeed  WindDirection  \
# 0         6.0          33.0              92.0        0.0            0.0
# 1         6.0          33.0              96.0        0.0            0.0
# 2         5.0          33.0              96.0        0.0            0.0
# 3         5.0          33.0              96.0        0.0            0.0
# 4         5.0          33.0              92.0        0.0            0.0
#
#    SeaLevelPressure  Precip
# 0             29.99    0.01
# 1             29.99    0.02
# 2             29.99    0.02
# 3             29.97    0.02
# 4             29.96    0.02

# %%
pd.DataFrame(scaled_df , columns = ["DRYBULBTEMPF",	"RelativeHumidity"	,"WindSpeed"	,"WindDirection"	,"SeaLevelPressure",	"Precip"] ).iloc[400:405 , :]
# Out:
#      DRYBULBTEMPF  RelativeHumidity  WindSpeed  WindDirection  \
# 400     -0.940285          1.215545   1.105844      -1.175117
# 401     -0.940285          1.416562   0.614122      -1.267974
# 402     -0.940285          1.567325  -0.041508      -1.360831
# 403     -0.882795          1.416562   0.286307      -1.360831
# 404     -0.882795          1.416562   1.433658      -1.360831
#
#      SeaLevelPressure    Precip
# 400         -0.837574  0.678127
# 401         -0.923020  1.231209
# 402         -1.051188  3.996616
# 403         -1.264802  1.507750
# 404         -1.563862  1.231209

# %%
pd.DataFrame(scaled_df , columns = ["DRYBULBTEMPF",	"RelativeHumidity"	,"WindSpeed"	,"WindDirection"	,"SeaLevelPressure",	"Precip"] ).to_csv("SData.csv" , index=False)
